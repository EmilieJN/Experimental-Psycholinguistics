# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
x = '42'
type(x)
# Out:
# str

# %% [markdown]
# ## Integers

# %%
y = 42
type(y)
# Out:
# int

# %% [markdown]
# ## Floats

# %%
z = 42.1
type(z)
# Out:
# float

# %% [markdown]
# ## Lists

# %%
weekend = ['friday', 'saturday', 'sunday']
type(weekend)
# Out:
# list

# %%
len(weekend)
# Out:
# 3

# %%
print(weekend[0])
# Out:
# friday

# %%
weekend[-1]
# Out:
# 'sunday'

# %%
list = [1,2,3]
list[0]=3
print(list)
# Out:
# [3, 2, 3]

# %% [markdown]
# ## Tuples

# %%
weekdays = ('monday', 'tuesday', 'wednesday')
type(weekdays)
# Out:
# tuple

# %%
len(weekdays)
# Out:
# 3

# %%
day4 = ('thursday',)
type(day4)
# Out:
# tuple

# %%
week = [weekend, weekdays, day4]
print(week[1][0])
# Out:
# monday

# %%
print(week[0][0])
# Out:
# friday

# %% [markdown]
# ## Sets

# %%
colours = ['blue', 'blue', 'green', 43, 42, 42,]
MySet= set(colours)
print(MySet)
# Out:
# {'green', 'blue', 42, 43}

# %%
len(MySet)
# Out:
# 4

# %%
len(colours)
# Out:
# 6

# %%
set = {1,2,3}
set

# %% [markdown]
# ## Dictionaries

# %%
me = {'name':'Emilie'}
print(me['name'])
# Out:
# Emilie

# %%
my_pet = {'name':'frække',
         'species':'cat'}
print(my_pet['species'])
# Out:
# cat

# %%
meals = {'breakfast':['skyr','chia','oats'],
          'dinner': ('egg', 'tzatziki')}
print(meals['breakfast'])
# Out:
# ['skyr', 'chia', 'oats']

# %%
items = ['skyr', ['salt', 'chili'], 'oats']
amount = [1,2,1]

# %%
shopping = {'items':items, 'amount':amount}
print(shopping['amount'])
# Out:
# [1, 2, 1]

# %%
shopping['items'][1]
# Out:
# ['salt', 'chili']

# %%
shopping['items'][1][0]
# Out:
# 'salt'

# %%
things = ['grapes','skyr',['salt','chili'],shopping]

# %%
thingDict = {'shopping':shopping, 'amount':amount, 'things':things}

# %%
thingDict['things']
# Out:
# ['grapes',
#  'skyr',
#  ['salt', 'chili'],
#  {'items': ['skyr', ['salt', 'chili'], 'oats'], 'amount': [1, 2, 1]}]

# %%
thingDict['things'][3]
# Out:
# {'items': ['skyr', ['salt', 'chili'], 'oats'], 'amount': [1, 2, 1]}

# %%
thingDict['things'][3]['items']
# Out:
# ['skyr', ['salt', 'chili'], 'oats']

# %%
thingDict['things'][3]['items'][1][1]
# Out:
# 'chili'
