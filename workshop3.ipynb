# %%
import pandas as pd

# %%
raw = pd.read_csv('/work/Experimental-Psycholinguistics/combined_data.csv')

# %% [markdown]
# the .head() command shows tthe amount of rows you want from the top. with no number in the bracket, you get the first five. using .tail() shows you the last five.

# %%
#raw.head(20)

# %%
list(raw)
# gives you the list of the column names. makes it easy to copy so you can pick the columns that are relevant.
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
'participant_id' 'duration' 'sender' 'soa_condition' 'response' 'prime' 'target' 'condition' 'congruence'
# Out:
# 'participant_iddurationsendersoa_conditionresponseprimetargetconditioncongruence'

# %%
cols = ['participant_id', 'sender', 'duration', 'prime', 'target', 'response', 'condition', 'soa_condition',  'congruence', 'correct_response', 'correct']

# %%
df = raw[cols]

# %%
df = df[df['sender'] == 'target']

# %%
sender_list = list(df['sender'])
set(sender_list)
# set shows the duplicates
# Out:
# {'target'}

# %%
df['sender'].unique()
#specific pandas command
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str

# %%
df = df[df['condition'] != 'practice']
# look through the condition column and find everything that is not practice
# normally Ethan would prefer to have a separate column for practice / not practice

# %%
df = df.drop(columns=['sender'])
df
# drop removes the sender column as we no longer need it
# Out:
#        participant_id  duration  prime target response        condition  \
# 40                 51    520.14   roof  PIANO        m  Inc_Synth_Synth
# 47                 51    640.66  sheep   BULL        n      Inc_Nat_Nat
# 54                 51    597.74   fort   GOAT        n    Inc_Synth_Nat
# 61                 51    495.68   pear   PEAR        n          Con_Nat
# 68                 51    556.86  olive  MOTOR        m    Inc_Nat_Synth
# ...               ...       ...    ...    ...      ...              ...
# 15606              69    699.20   belt   BELT        m        Con_Synth
# 15612              69    580.20  daisy  DAISY        n          Con_Nat
# 15618              69    577.90  peach   SHED        m    Inc_Nat_Synth
# 15624              69    661.10   rake  HUSKY        n    Inc_Synth_Nat
# 15630              69    709.20   fern  PETAL        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# ...

# %%
df.loc[df['target'] == 'BULL', 'correct_response'] = 'n'
df.loc[df['target'] == 'BULL', 'correct'] = 'True'
# fixing a mistake in the experiment

# %%
df['accuracy']= df['response'] == df['correct_response']
df = df.drop(columns=['correct'])
df
# Out:
#        participant_id  duration  prime target response        condition  \
# 40                 51    520.14   roof  PIANO        m  Inc_Synth_Synth
# 47                 51    640.66  sheep   BULL        n      Inc_Nat_Nat
# 54                 51    597.74   fort   GOAT        n    Inc_Synth_Nat
# 61                 51    495.68   pear   PEAR        n          Con_Nat
# 68                 51    556.86  olive  MOTOR        m    Inc_Nat_Synth
# ...               ...       ...    ...    ...      ...              ...
# 15606              69    699.20   belt   BELT        m        Con_Synth
# 15612              69    580.20  daisy  DAISY        n          Con_Nat
# 15618              69    577.90  peach   SHED        m    Inc_Nat_Synth
# 15624              69    661.10   rake  HUSKY        n    Inc_Synth_Nat
# 15630              69    709.20   fern  PETAL        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response  accuracy
# ...

# %%
#df_grouped = df.groupby(['soa_condition','congruence']).mean(['duration'])
# i can run .groupby without the .mean, but the result is still odd.
# with .mean, it doesn't work at all. error that calls for Boolean value

# %%
#df_grouped = df_grouped.reset_index()
#df_grouped
#should show us a nice, simple pandas dataframe / table

# %%
# matplotlib is a powerful package for creating graphs that is really horrible to work with
# seaborn is a package that makes it way simpler to do

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
#ax = sns.barplot(data=df_grouped, x = 'soa_condition', y = 'duration', hue = 'congruence')
# = sns.plottype(data=the data in question, x = IV, y = DV, hue = IV2)
# ax is the name of the plot

# %%
#sns.move_legend(ax,"lower right")
# this moves the explanation/legend from covering the top to not
